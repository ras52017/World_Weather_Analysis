# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

type(lat_lngs)
# Out:
# zip

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(-72.30576314554618, 15.239829789789553), (25.89147527595641, -153.15274172253092), (60.82357690158938, 26.210122402404124), (18.732958096016958, -14.977548752990288), (19.270510480209722, 57.12095701257084), (47.24044360458012, -168.31395448116064), (47.591238620928266, 160.16596802146904), (17.214338006159466, 134.630800062613), (43.655162725260936, 179.16673339390616), (53.245924358914095, 118.10366816004944), (52.967948349872785, 101.40622627775872), (-48.3829068016017, -5.920741551898033), (79.46230082497283, 54.715963374491025), (-22.594566177509236, 58.7157024061427), (77.36767841422648, -51.40533795381569), (-13.454425762117609, -145.59806219771284), (54.55190934805066, 163.82294391584446), (-78.24409948523795, 38.004647700382804), (-87.5141926478741, 84.56370120220635), (-76.0265498116615, -169.15677838987233), (-43.04340930009511, -7.608783369392825), (-31.028350593869988, 94.89574161194912), (-61.455345317540846, -56.73815132295053), (-5.150215079264768, -27.504419335321046), (77.38118259048821, 124.29241779458386), (-82.7153412922284, -41.36892617769561), (70.65793286111591, -123.3607344788503), (-66.40404294615759, -80.20886765435168), (89.2291006217198, 58.16438311237545), (74.83894122335184, 167.821440617596), (-88.24168193320293, 10.75016212334532), (-57.93838422472011, 163.92888771125484), (-84.73049707984707, 21.139207233295394), (47.87423048620198, -156.7143509428844), (65.78940408288906, -68.1594558546645), (-13.135449748883161, -161.21598184725772), (-56.17787269950144, -16.44761726387813), (37.29319859995515, 165.88235387153168), (11.09752313540669, -7.937214667536978), (3.3162826853428697, -155.42676276074354), (37.160923627339, 161.20363778454475), (10.56269238918604, -176.98819272742352), (46.23683037859831, -139.09967163055234), (24.287220424215178, 132.11122077484112), (41.35002878266292, 63.00930547824183), (33.39194628380031, 121.88933166447526), (76.96034668271446, -107.50790743003394), (47.372143842376914, -133.04448341165846), (-52.4770596567498, -149.01480493859054), (-60.92940304976668, 170.91087475432056), (-49.405386666396204, 112.80549414070833), (28.91864827037938, 55.5791860797857), (24.307054939475094, 73.5840699746426), (-34.57079147843627, -84.06587136682343), (-75.40489816696135, 149.99701055430342), (-18.6872260110745, 59.27507455479608), (68.35633957198371, -134.43124884288), (-16.65151849400185, 7.55411177376422), (22.966424416696697, 140.0379420149418), (63.29094467637725, -31.035317932907788), (-80.38791086386244, -21.876506621112014), (-39.51095187415083, -13.783009115802486), (-70.11264996447501, 60.43515821836937), (76.2081487817587, -39.255282690216916), (-22.518817237079332, -160.4874039008727), (74.72985879264829, 117.13427714492019), (87.7800615853431, 169.99447282468367), (-36.06266272670765, -49.50781978077404), (-2.5589652415625324, -7.341181968458642), (-7.371960791699735, 158.0516429687039), (18.019661131289553, -118.21746805521127), (-26.23360099960002, -35.1371317223865), (4.571303161539674, 8.796251385720097), (18.925289100648484, -152.12144199969174), (2.573910366765787, 74.44109499112847), (69.96727943612149, 38.79251743303928), (80.63084396781227, 173.51122876203914), (-32.7506574659549, -172.22969477761157), (-20.719344998240416, -90.74526766912902), (9.841243448431698, 122.50294272178832), (-67.60033281039752, 159.6725305417902), (63.08262300034346, -147.11162435880667), (-78.99357236659002, -48.323141560874916), (-31.084189351669146, 13.498858500487074), (-22.85308931599164, 131.47167530350094), (23.582881435559997, -177.55573611606184), (-58.51477695175342, 43.54938119226924), (-23.82557961459041, -54.37959900041652), (-73.73297436911102, 158.96344461286293), (-52.27011179669071, 102.09141284311295), (45.14772699847313, -179.03670736335152), (64.3911292391436, -2.230227850244404), (86.86125022226923, -3.184055093331864), (66.94335679951843, 177.74693063052712), (22.117965501878714, 102.6246789880226), (-43.77336120972413, -102.76774809877095), (-2.784355208 ...

# %%
coordinates[0][1]
# Out:
# 15.239829789789553

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
# YOUR CODE HERE
url= "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
                
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE  
        lat=city_weather["coord"]["lat"]
        lon=city_weather["coord"]["lon"]
        max_temp=city_weather["main"]["temp_max"]
        humidity=city_weather["main"]["humidity"]
        cloudiness=city_weather["clouds"]["all"]
        wind=city_weather["wind"]["speed"]
        country=city_weather["sys"]["country"]
        description=city_weather["weather"][0]["description"]
        city =city_weather["name"]
        # Append the city information into the city_data list
        # YOUR CODE HERE,
        
        city_data.append({"latitud": lat,
                         "longitude": lon,
                         "temperature": max_temp,
                         "humidity":humidity,
                         "cloudiness":cloudiness,
                         "wind_speed": wind,
                         "country":country,
                         "description":description,
                         "city":city})
            # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | kahului
# Processing Record 3 of Set 1 | nastola
# Processing Record 4 of Set 1 | nouakchott
# Processing Record 5 of Set 1 | nizwa
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | severo-kurilsk
# Processing Record 8 of Set 1 | airai
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | ksenyevka
# City not found. Skipping...
# Processing Record 11 of Set 1 | zima
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | souillac
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | tiarei
# Processing Record 17 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | carnarvon
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | cabedelo
# Processing Record 25 of Set 1 | tiksi
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | pevek
# Processing Record 29 of Set 1 | hermanus
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | iqaluit
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | bougouni
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | sitka
# Processing Record 38 of Set 1 | gushikawa
# Processing Record 39 of Set 1 | gazli
# Processing Record 40 of Set 1 | juegang
# Processing Record 41 of Set 1 | yellowknife
# Processing Record 42 of Set 1 | port hardy
# Processing Record 43 of Set 1 | mataura
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | sirjan
# Processing Record 46 of Set 1 | dungarpur
# Processing Record 47 of Set 1 | lebu
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | grand gaube
# Processing Record 50 of Set 1 | aklavik
# Processing Record 1 of Set 2 | namibe
# Processing Record 2 of Set 2 | shingu
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | saskylakh
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | harper
# Processing Record 8 of Set 2 | gizo
# Processing Record 9 of Set 2 | constitucion
# Processing Record 10 of Set 2 | sao joao da barra
# Processing Record 11 of Set 2 | idenao
# Processing Record 12 of Set 2 | muli
# Processing Record 13 of Set 2 | ostrovnoy
# Processing Record 14 of Set 2 | pisco
# Processing Record 15 of Set 2 | canturay
# Processing Record 16 of Set 2 | fairbanks
# Processing Record 17 of Set 2 | oranjemund
# Processing Record 18 of Set 2 | yulara
# Processing Record 19 of Set 2 | east london
# Processing Record 20 of Set 2 | eldorado
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | brae
# Processing Record 23 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 2 | anadyr
# Processing Record 25 of Set 2 | dien bien
# City not found. Skipping...
# Processing Record 26 of Set 2 | castro
# Processing Record 27 of Set 2 | djambala
# Processing Record 28 of Set 2 | xapuri
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | beruwala
# Processing Record 33 of Set 2 | srednekolymsk
# Processing Record 34 of Set 2 | winslow
# Processing Record 35 of Set 2 | morgan city
# Processing Record 36 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | ancud
# Processing Record 39 of Set 2 | esperance
# Processing Record 40 of Set 2 | pangnirtung
# Processing Record 41 of Set 2 | fort nelson
# Processing Record 42 of Set 2 | rikitea
# Processing Record 43 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 2 | wloclawek
# Processing Record 45 of Set 2 | batemans bay
# Processing Record 46 of Set 2 | rayachoti
# Processing Record 47 of Set 2 | atuona
# Processing Record 48 of Set 2 | zunheboto
# Processing Record 49 of Set 2 | georgetown
# Processing Record 50 of Set 2 | dingle
# Processing Record 1 of Set 3 | great yarmouth
# Processing Record 2 of Set 3 | olhao
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 3 | asekeyevo
# Processing Record 6 of Set 3 | college
# Processing Record 7 of Set 3 | poum
# Processing Record 8 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 3 | sept-iles
# Processing Record 10 of Set 3 | atasu
# Processing Record 11 of Set 3 | sioux lookout
# Processing Record 12 of Set 3 | chokurdakh
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | new norfolk
# Processing Record 15 of Set 3 | kloulklubed
# Processing Record 16 of Set 3 | lander
# Processing Record 17 of Set 3 | taoudenni
# Processing Record 18 of Set 3 | faanui
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | la ronge
# Processing Record 21 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 3 | butaritari
# Processing Record 23 of Set 3 | buala
# Processing Record 24 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | zamboanguita
# Processing Record 26 of Set 3 | olafsvik
# Processing Record 27 of Set 3 | tura
# Processing Record 28 of Set 3 | cabot
# Processing Record 29 of Set 3 | luderitz
# Processing Record 30 of Set 3 | rantepao
# Processing Record 31 of Set 3 | bubaque
# Processing Record 32 of Set 3 | saint-leu
# Processing Record 33 of Set 3 | chapais
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 3 | birpur
# Processing Record 36 of Set 3 | lorengau
# Processing Record 37 of Set 3 | pavilosta
# Processing Record 38 of Set 3 | cayenne
# Processing Record 39 of Set 3 | pangody
# Processing Record 40 of Set 3 | iskateley
# Processing Record 41 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 3 | sao filipe
# Processing Record 43 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 3 | cidreira
# Processing Record 45 of Set 3 | arlit
# Processing Record 46 of Set 3 | castellarano
# Processing Record 47 of Set 3 | husavik
# Processing Record 48 of Set 3 | obo
# Processing Record 49 of Set 3 | madingou
# Processing Record 50 of Set 3 | nuuk
# Processing Record 1 of Set 4 | hamilton
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | palu
# Processing Record 4 of Set 4 | yenagoa
# Processing Record 5 of Set 4 | bundaberg
# Processing Record 6 of Set 4 | dullewala
# Processing Record 7 of Set 4 | nouadhibou
# Processing Record 8 of Set 4 | honningsvag
# Processing Record 9 of Set 4 | murgab
# Processing Record 10 of Set 4 | gallatin
# Processing Record 11 of Set 4 | bozhou
# Processing Record 12 of Set 4 | angoche
# Processing Record 13 of Set 4 | trairi
# Processing Record 14 of Set 4 | nhulunbuy
# Processing Record 15 of Set 4 | berlin
# Processing Record 16 of Set 4 | ahipara
# Processing Record 17 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | arraial do cabo
# Processing Record 19 of Set 4 | vanavara
# Processing Record 20 of Set 4 | calahorra
# Processing Record 21 of Set 4 | tabas
# Processing Record 22 of Set 4 | uniontown
# Processing Record 23 of Set 4 | beira
# Processing Record 24 of Set 4 | santa rosa
# Processing Record 25 of Set 4 | victoria
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | calabozo
# Processing Record 28 of Set 4 | narsaq
# Processing Record 29 of Set 4 | cherskiy
# Processing Record 30 of Set 4 | ayacucho
# Processing Record 31 of Set 4 | tuktoyaktuk
# Processing Record 32 of Set 4 | chabahar
# Processing Record 33 of Set 4 | aksu
# Processing Record 34 of Set 4 | wad madani
# Processing Record 35 of Set 4 | santiago del estero
# Processing Record 36 of Set 4 | ukiah
# Processing Record 37 of Set 4 | brigantine
# Processing Record 38 of Set 4 | dikson
# Processing Record 39 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 4 | ketchikan
# Processing Record 41 of Set 4 | tuni
# Processing Record 42 of Set 4 | tuatapere
# Processing Record 43 of Set 4 | miracema do tocantins
# Processing Record 44 of Set 4 | sakakah
# Processing Record 45 of Set 4 | minab
# Processing Record 46 of Set 4 | narva-joesuu
# Processing Record 47 of Set 4 | gort
# Processing Record 48 of Set 4 | quatre cocos
# Processing Record 49 of Set 4 | banswada
# Processing Record 50 of Set 4 | chake chake
# Processing Record 1 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 2 of Set 5 | hasaki
# Processing Record 3 of Set 5 | mvuma
# Processing Record 4 of Set 5 | flinders
# Processing Record 5 of Set 5 | ayni
# Processing Record 6 of Set 5 | nelson
# Processing Record 7 of Set 5 | leningradskiy
# Processing Record 8 of Set 5 | cabo san lucas
# Processing Record 9 of Set 5 | cam ranh
# Processing Record 10 of Set 5 | aitape
# Processing Record 11 of Set 5 | diffa
# Processing Record 12 of Set 5 | huambo
# Processing Record 13 of Set 5 | haimen
# Processing Record 14 of Set 5 | kouvola
# Processing Record 15 of Set 5 | teguise
# Processing Record 16 of Set 5 | marv dasht
# City not found. Skipping...
# Processing Record 17 of Set 5 | guerrero negro
# Processing Record 18 of Set 5 | caxito
# Processing Record 19 of Set 5 | colares
# Processing Record 20 of Set 5 | manzil jamil
# City not found. Skipping...
# Processing Record 21 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 5 | tieli
# Processing Record 23 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 5 | ambon
# Processing Record 25 of Set 5 | hobyo
# Processing Record 26 of Set 5 | port elizabeth
# Processing Record 27 of Set 5 | ilo
# Processing Record 28 of Set 5 | taft
# Processing Record 29 of Set 5 | mahebourg
# Processing Record 30 of Set 5 | pandharpur
# Processing Record 31 of Set 5 | egvekinot
# Processing Record 32 of Set 5 | tutoia
# Processing Record 33 of Set 5 | maymyo
# Processing Record 34 of Set 5 | talnakh
# Processing Record 35 of Set 5 | port hedland
# Processing Record 36 of Set 5 | katsuura
# Processing Record 37 of Set 5 | yeppoon
# Processing Record 38 of Set 5 | nantucket
# Processing Record 39 of Set 5 | caravelas
# Processing Record 40 of Set 5 | kavaratti
# Processing Record 41 of Set 5 | adolfo lopez mateos
# Processing Record 42 of Set 5 | mahibadhoo
# Processing Record 43 of Set 5 | uk
# City not found. Skipping...
# Processing Record 44 of Set 5 | baker city
# Processing Record 45 of Set 5 | deputatskiy
# Processing Record 46 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 5 | nemuro
# Processing Record 48 of Set 5 | rehoboth
# Processing Record 49 of Set 5 | rundu
# Processing Record 50 of Set 5 | palmer
# Processing Record 1 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 2 of Set 6 | los llanos de aridane
# Processing Record 3 of Set 6 | mount gambier
# Processing Record 4 of Set 6 | sawakin
# Processing Record 5 of Set 6 | kieta
# Processing Record 6 of Set 6 | beitbridge
# Processing Record 7 of Set 6 | merrill
# Processing Record 8 of Set 6 | sol-iletsk
# Processing Record 9 of Set 6 | floro
# Processing Record 10 of Set 6 | saint-augustin
# Processing Record 11 of Set 6 | mount isa
# Processing Record 12 of Set 6 | weiser
# Processing Record 13 of Set 6 | aranos
# Processing Record 14 of Set 6 | xining
# Processing Record 15 of Set 6 | port blair
# Processing Record 16 of Set 6 | odweyne
# Processing Record 17 of Set 6 | smirnykh
# Processing Record 18 of Set 6 | teya
# Processing Record 19 of Set 6 | tvoroyri
# Processing Record 20 of Set 6 | kaitangata
# Processing Record 21 of Set 6 | tautira
# Processing Record 22 of Set 6 | lasa
# Processing Record 23 of Set 6 | sechura
# Processing Record 24 of Set 6 | sokoni
# Processing Record 25 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 26 of Set 6 | lima
# Processing Record 27 of Set 6 | naze
# Processing Record 28 of Set 6 | moerai
# Processing Record 29 of Set 6 | luganville
# Processing Record 30 of Set 6 | paungde
# Processing Record 31 of Set 6 | port-cartier
# Processing Record 32 of Set 6 | enid
# Processing Record 33 of Set 6 | trinidad
# Processing Record 34 of Set 6 | sharlyk
# Processing Record 35 of Set 6 | cookeville
# Processing Record 36 of Set 6 | inhambane
# Processing Record 37 of Set 6 | kalanguy
# Processing Record 38 of Set 6 | bayanday
# Processing Record 39 of Set 6 | yantal
# Processing Record 40 of Set 6 | chimbote
# Processing Record 41 of Set 6 | biak
# Processing Record 42 of Set 6 | naryan-mar
# Processing Record 43 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 6 | saint-philippe
# Processing Record 45 of Set 6 | pau
# Processing Record 46 of Set 6 | griffith
# Processing Record 47 of Set 6 | geraldton
# Processing Record 48 of Set 6 | longyearbyen
# Processing Record 49 of Set 6 | port augusta
# Processing Record 50 of Set 6 | abrau-dyurso
# Processing Record 1 of Set 7 | saldanha
# Processing Record 2 of Set 7 | te anau
# Processing Record 3 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 4 of Set 7 | bengkulu
# Processing Record 5 of Set 7 | kargopol
# Processing Record 6 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 7 | awbari
# Processing Record 8 of Set 7 | sorong
# Processing Record 9 of Set 7 | ribeira grande
# Processing Record 10 of Set 7 | high rock
# Processing Record 11 of Set 7 | coquimbo
# Processing Record 12 of Set 7 | kirensk
# Processing Record 13 of Set 7 | kalavrita
# City not found. Skipping...
# Processing Record 14 of Set 7 | peniche
# Processing Record 15 of Set 7 | hithadhoo
# Processing Record 16 of Set 7 | solnechnyy
# Processing Record 17 of Set 7 | nelson bay
# Processing Record 18 of Set 7 | gbarnga
# Processing Record 19 of Set 7 | sassandra
# Processing Record 20 of Set 7 | beyneu
# Processing Record 21 of Set 7 | urengoy
# Processing Record 22 of Set 7 | genhe
# Processing Record 23 of Set 7 | redmond
# Processing Record 24 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 25 of Set 7 | tamiahua
# Processing Record 26 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 27 of Set 7 | issa
# Processing Record 28 of Set 7 | verkhnevilyuysk
# Processing Record 29 of Set 7 | imbituba
# Processing Record 30 of Set 7 | ozernovskiy
# Processing Record 31 of Set 7 | saint-francois
# Processing Record 32 of Set 7 | luan
# Processing Record 33 of Set 7 | fortuna
# Processing Record 34 of Set 7 | buchanan
# Processing Record 35 of Set 7 | tilichiki
# Processing Record 36 of Set 7 | uyuni
# Processing Record 37 of Set 7 | santa maria
# Processing Record 38 of Set 7 | faya
# Processing Record 39 of Set 7 | sobral
# Processing Record 40 of Set 7 | aras
# Processing Record 41 of Set 7 | korla
# Processing Record 42 of Set 7 | havre
# Processing Record 43 of Set 7 | roma
# Processing Record 44 of Set 7 | challans
# Processing Record 45 of Set 7 | myitkyina
# Processing Record 46 of Set 7 | nagornskiy
# Processing Record 47 of Set 7 | acajutla
# Processing Record 48 of Set 7 | hosur
# Processing Record 49 of Set 7 | hambantota
# Processing Record 50 of Set 7 | atar
# Processing Record 1 of Set 8 | clyde river
# Processing Record 2 of Set 8 | vila velha
# Processing Record 3 of Set 8 | anacortes
# Processing Record 4 of Set 8 | cascais
# Processing Record 5 of Set 8 | sambava
# Processing Record 6 of Set 8 | itarema
# Processing Record 7 of Set 8 | vidim
# Processing Record 8 of Set 8 | shahrud
# Processing Record 9 of Set 8 | linfen
# Processing Record 10 of Set 8 | san cristobal
# Processing Record 11 of Set 8 | vao
# Processing Record 12 of Set 8 | shubarshi
# Processing Record 13 of Set 8 | walvis bay
# Processing Record 14 of Set 8 | touros
# Processing Record 15 of Set 8 | show low
# Processing Record 16 of Set 8 | lufilufi
# Processing Record 17 of Set 8 | mamou
# Processing Record 18 of Set 8 | avera
# Processing Record 19 of Set 8 | san isidro
# Processing Record 20 of Set 8 | margate
# Processing Record 21 of Set 8 | klaksvik
# Processing Record 22 of Set 8 | boden
# Processing Record 23 of Set 8 | misratah
# Processing Record 24 of Set 8 | hovd
# Processing Record 25 of Set 8 | ishinomaki
# Processing Record 26 of Set 8 | alofi
# Processing Record 27 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 28 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 29 of Set 8 | yangshe
# Processing Record 30 of Set 8 | aksay
# Processing Record 31 of Set 8 | cherkasskoye
# Processing Record 32 of Set 8 | puerto ayacucho
# Processing Record 33 of Set 8 | ponerihouen
# Processing Record 34 of Set 8 | camana
# Processing Record 35 of Set 8 | osmena
# Processing Record 36 of Set 8 | alyangula
# Processing Record 37 of Set 8 | ko samui
# Processing Record 38 of Set 8 | sinaloa
# Processing Record 39 of Set 8 | council bluffs
# Processing Record 40 of Set 8 | nha trang
# Processing Record 41 of Set 8 | bathsheba
# Processing Record 42 of Set 8 | fonte boa
# Processing Record 43 of Set 8 | lavrentiya
# Processing Record 44 of Set 8 | zlobin
# Processing Record 45 of Set 8 | cap malheureux
# Processing Record 46 of Set 8 | xinzhou
# Processing Record 47 of Set 8 | luis correia
# Processing Record 48 of Set 8 | rio gallegos
# Processing Record 49 of Set 8 | saint-georges
# Processing Record 50 of Set 8 | havre-saint-pierre
# Processing Record 1 of Set 9 | oildale
# Processing Record 2 of Set 9 | shirokiy
# Processing Record 3 of Set 9 | vardo
# Processing Record 4 of Set 9 | roald
# Processing Record 5 of Set 9 | port-gentil
# Processing Record 6 of Set 9 | sapao
# City not found. Skipping...
# Processing Record 7 of Set 9 | meulaboh
# Processing Record 8 of Set 9 | lena
# Processing Record 9 of Set 9 | pitimbu
# Processing Record 10 of Set 9 | flin flon
# Processing Record 11 of Set 9 | posevnaya
# Processing Record 12 of Set 9 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 9 | padang
# Processing Record 14 of Set 9 | karaton
# Processing Record 15 of Set 9 | el retorno
# Processing Record 16 of Set 9 | kamen-na-obi
# Processing Record 17 of Set 9 | passagem franca
# Processing Record 18 of Set 9 | kutum
# Processing Record 19 of Set 9 | maniitsoq
# Processing Record 20 of Set 9 | slave lake
# Processing Record 21 of Set 9 | leshukonskoye
# Processing Record 22 of Set 9 | kholm-zhirkovskiy
# Processing Record 23 of Set 9 | metro
# Processing Record 24 of Set 9 | altay
# Processing Record 25 of Set 9 | nantai
# Processing Record 26 of Set 9 | yanaul
# Processing Record 27 of Set 9 | uyemskiy
# Processing Record 28 of Set 9 | sabang
# Processing Record 29 of Set 9 | najran
# Processing Record 30 of Set 9 | tuscaloosa
# Processing Record 31 of Set 9 | batagay-alyta
# Processing Record 32 of Set 9 | aksarka
# Processing Record 33 of Set 9 | kruisfontein
# Processing Record 34 of Set 9 | kokoda
# Processing Record 35 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 36 of Set 9 | isangel
# Processing Record 37 of Set 9 | sorland
# Processing Record 38 of Set 9 | gat
# Processing Record 39 of Set 9 | bambous virieux
# Processing Record 40 of Set 9 | usinsk
# Processing Record 41 of Set 9 | saint george
# Processing Record 42 of Set 9 | devrek
# Processing Record 43 of Set 9 | abu dhabi
# Processing Record 44 of Set 9 | muisne
# Processing Record 45 of Set 9 | mulchen
# Processing Record 46 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 9 | ginda
# Processing Record 48 of Set 9 | muzhi
# Processing Record 49 of Set 9 | nogliki
# Processing Record 50 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 10 | malanje
# Processing Record 2 of Set 10 | port macquarie
# Processing Record 3 of Set 10 | callaway
# Processing Record 4 of Set 10 | sheboygan
# Processing Record 5 of Set 10 | krasnoselkup
# Processing Record 6 of Set 10 | bytosh
# Processing Record 7 of Set 10 | asyut
# Processing Record 8 of Set 10 | tezu
# Processing Record 9 of Set 10 | sibu
# Processing Record 10 of Set 10 | mae hong son
# Processing Record 11 of Set 10 | iranshahr
# Processing Record 12 of Set 10 | nome
# Processing Record 13 of Set 10 | ponta do sol
# Processing Record 14 of Set 10 | zhuhai
# Processing Record 15 of Set 10 | alpoyeca
# Processing Record 16 of Set 10 | taveta
# Processing Record 17 of Set 10 | viedma
# Processing Record 18 of Set 10 | carbonia
# Processing Record 19 of Set 10 | ilulissat
# Processing Record 20 of Set 10 | bayonne
# Processing Record 21 of Set 10 | petrivka
# Processing Record 22 of Set 10 | manokwari
# Processing Record 23 of Set 10 | lakes entrance
# Processing Record 24 of Set 10 | anloga
# Processing Record 25 of Set 10 | hofn
# Processing Record 26 of Set 10 | north bend
# Processing Record 27 of Set 10 | mayo
# Processing Record 28 of Set 10 | beringovskiy
# Processing Record 29 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 10 | karratha
# Processing Record 31 of Set 10 | salalah
# Processing Record 32 of Set 10 | ucluelet
# Processing Record 33 of Set 10 | xiongzhou
# Processing Record 34 of Set 10 | la macarena
# Processing Record 35 of Set 10 | torbay
# Processing Record 36 of Set 10 | tomatlan
# Processing Record 37 of Set 10 | buraydah
# Processing Record 38 of Set 10 | san quintin
# Processing Record 39 of Set 10 | honiara
# Processing Record 40 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 10 | muhos
# Processing Record 43 of Set 10 | cordon
# Processing Record 44 of Set 10 | matay
# Processing Record 45 of Set 10 | quang ngai
# Processing Record 46 of Set 10 | san felipe
# Processing Record 47 of Set 10 | safaga
# Processing Record 48 of Set 10 | bekhtery
# Processing Record 49 of Set 10 | mazurivka
# Processing Record 50 of Set 10 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 11 | ekibastuz
# Processing Record 2 of Set 11 | doha
# Processing Record 3 of Set 11 | berdigestyakh
# Processing Record 4 of Set 11 | dunedin
# Processing Record 5 of Set 11 | non sang
# Processing Record 6 of Set 11 | birao
# Processing Record 7 of Set 11 | mao
# Processing Record 8 of Set 11 | nioki
# Processing Record 9 of Set 11 | mongo
# Processing Record 10 of Set 11 | codrington
# Processing Record 11 of Set 11 | madison heights
# Processing Record 12 of Set 11 | san jose
# Processing Record 13 of Set 11 | robinson
# Processing Record 14 of Set 11 | bumba
# Processing Record 15 of Set 11 | pakxan
# Processing Record 16 of Set 11 | le port
# Processing Record 17 of Set 11 | borba
# Processing Record 18 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 19 of Set 11 | ialibu
# Processing Record 20 of Set 11 | lingao
# Processing Record 21 of Set 11 | puerto el triunfo
# Processing Record 22 of Set 11 | bijie
# Processing Record 23 of Set 11 | aasiaat
# Processing Record 24 of Set 11 | madras
# Processing Record 25 of Set 11 | impfondo
# Processing Record 26 of Set 11 | keti bandar
# Processing Record 27 of Set 11 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 28 of Set 11 | broken hill
# Processing Record 29 of Set 11 | gazanjyk
# Processing Record 30 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 31 of Set 11 | wasilla
# Processing Record 32 of Set 11 | desaguadero
# Processing Record 33 of Set 11 | kaeo
# Processing Record 34 of Set 11 | almeirim
# Processing Record 35 of Set 11 | along
# Processing Record 36 of Set 11 | jacareacanga
# Processing Record 37 of Set 11 | varzea grande
# Processing Record 38 of Set 11 | sorochinsk
# Processing Record 39 of Set 11 | sosnovo
# Processing Record 40 of Set 11 | makaryev
# Processing Record 41 of Set 11 | sawtell
# Processing Record 42 of Set 11 | ostersund
# Processing Record 43 of Set 11 | pithiviers
# Processing Record 44 of Set 11 | binzhou
# Processing Record 45 of Set 11 | nizhniy baskunchak
# Processing Record 46 of Set 11 | berlevag
# Processing Record 47 of Set 11 | presidencia roque saenz pena
# Processing Record 48 of Set 11 | abu samrah
# Processing Record 49 of Set 11 | qianan
# Processing Record 50 of Set 11 | fukue
# Processing Record 1 of Set 12 | surt
# Processing Record 2 of Set 12 | roebourne
# Processing Record 3 of Set 12 | thabazimbi
# Processing Record 4 of Set 12 | santa vitoria do palmar
# Processing Record 5 of Set 12 | jalu
# Processing Record 6 of Set 12 | guia lopes da laguna
# Processing Record 7 of Set 12 | henties bay
# Processing Record 8 of Set 12 | ailigandi
# Processing Record 9 of Set 12 | basco
# Processing Record 10 of Set 12 | san juan
# Processing Record 11 of Set 12 | asfi
# Processing Record 12 of Set 12 | badiraguato
# Processing Record 13 of Set 12 | dabakala
# Processing Record 14 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 12 | kohat
# Processing Record 16 of Set 12 | bonga
# Processing Record 17 of Set 12 | saint paul
# Processing Record 18 of Set 12 | ust-koksa
# Processing Record 19 of Set 12 | sapouy
# Processing Record 20 of Set 12 | svetlaya
# Processing Record 21 of Set 12 | faranah
# Processing Record 22 of Set 12 | ancona
# Processing Record 23 of Set 12 | riyadh
# Processing Record 24 of Set 12 | tamandare
# Processing Record 25 of Set 12 | nicoya
# Processing Record 26 of Set 12 | kushima
# Processing Record 27 of Set 12 | three hills
# Processing Record 28 of Set 12 | bam
# Processing Record 29 of Set 12 | namatanai
# Processing Record 30 of Set 12 | olinda
# Processing Record 31 of Set 12 | eganville
# Processing Record 32 of Set 12 | cockburn town
# Processing Record 33 of Set 12 | markova
# Processing Record 34 of Set 12 | moose factory
# Processing Record 35 of Set 12 | alushta
# Processing Record 36 of Set 12 | dubti
# Processing Record 37 of Set 12 | urumqi
# Processing Record 38 of Set 12 | haines junction
# Processing Record 39 of Set 12 | muros
# Processing Record 40 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 41 of Set 12 | amahai
# Processing Record 42 of Set 12 | zirl
# Processing Record 43 of Set 12 | gloucester
# Processing Record 44 of Set 12 | adrar
# Processing Record 45 of Set 12 | necochea
# Processing Record 46 of Set 12 | marystown
# Processing Record 47 of Set 12 | takoradi
# Processing Record 48 of Set 12 | chicama
# Processing Record 49 of Set 12 | lensk
# Processing Record 50 of Set 12 | del rio
# Processing Record 1 of Set 13 | udachnyy
# Processing Record 2 of Set 13 | zheleznodorozhnyy
# Processing Record 3 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 13 | tocopilla
# Processing Record 5 of Set 13 | sarankhola
# Processing Record 6 of Set 13 | wang saphung
# Processing Record 7 of Set 13 | seoul
# Processing Record 8 of Set 13 | port charlotte
# Processing Record 9 of Set 13 | krivosheino
# Processing Record 10 of Set 13 | raudeberg
# Processing Record 11 of Set 13 | san luis
# Processing Record 12 of Set 13 | skala
# Processing Record 13 of Set 13 | sao jose da coroa grande
# Processing Record 14 of Set 13 | divo
# Processing Record 15 of Set 13 | tuy hoa
# Processing Record 16 of Set 13 | sao geraldo do araguaia
# Processing Record 17 of Set 13 | namtsy
# Processing Record 18 of Set 13 | tulum
# Processing Record 19 of Set 13 | gunjur
# Processing Record 20 of Set 13 | hohhot
# Processing Record 21 of Set 13 | pilar
# Processing Record 22 of Set 13 | vestmannaeyjar
# Processing Record 23 of Set 13 | grindavik
# Processing Record 24 of Set 13 | sisimiut
# Processing Record 25 of Set 13 | moree
# Processing Record 26 of Set 13 | taiyuan
# Processing Record 27 of Set 13 | linhai
# Processing Record 28 of Set 13 | jashpurnagar
# Processing Record 29 of Set 13 | poso
# Processing Record 30 of Set 13 | milkovo
# Processing Record 31 of Set 13 | port keats
# Processing Record 32 of Set 13 | huilong
# Processing Record 33 of Set 13 | hami
# Processing Record 34 of Set 13 | winsum
# Processing Record 35 of Set 13 | boyabat
# Processing Record 36 of Set 13 | ituiutaba
# Processing Record 37 of Set 13 | wilmington
# Processing Record 38 of Set 13 | inuvik
# Processing Record 39 of Set 13 | sarkand
# Processing Record 40 of Set 13 | long beach
# Processing Record 41 of Set 13 | maidenhead
# Processing Record 42 of Set 13 | sibolga
# Processing Record 43 of Set 13 | hirara
# Processing Record 44 of Set 13 | bonthe
# Processing Record 45 of Set 13 | matagami
# Processing Record 46 of Set 13 | portland
# Processing Record 47 of Set 13 | kaoma
# Processing Record 48 of Set 13 | omegna
# Processing Record 49 of Set 13 | tumut
# Processing Record 50 of Set 13 | corn island
# Processing Record 1 of Set 14 | manavgat
# Processing Record 2 of Set 14 | nampula
# Processing Record 3 of Set 14 | kuna
# Processing Record 4 of Set 14 | la romana
# Processing Record 5 of Set 14 | angra
# City not found. Skipping...
# Processing Record 6 of Set 14 | tshikapa
# Processing Record 7 of Set 14 | barcelos
# Processing Record 8 of Set 14 | menongue
# Processing Record 9 of Set 14 | albury
# Processing Record 10 of Set 14 | darnah
# Processing Record 11 of Set 14 | wuhu
# Processing Record 12 of Set 14 | camalu
# Processing Record 13 of Set 14 | pop
# Processing Record 14 of Set 14 | wukari
# Processing Record 15 of Set 14 | villacarrillo
# Processing Record 16 of Set 14 | carutapera
# Processing Record 17 of Set 14 | estelle
# Processing Record 18 of Set 14 | ixtapa
# Processing Record 19 of Set 14 | juneau
# Processing Record 20 of Set 14 | cedar city
# Processing Record 21 of Set 14 | razdolinsk
# Processing Record 22 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 23 of Set 14 | kunda
# Processing Record 24 of Set 14 | japura
# Processing Record 25 of Set 14 | kupang
# Processing Record 26 of Set 14 | bunbury
# Processing Record 27 of Set 14 | kolokani
# Processing Record 28 of Set 14 | mardin
# Processing Record 29 of Set 14 | hilton head island
# Processing Record 30 of Set 14 | kapuskasing
# Processing Record 31 of Set 14 | afua
# Processing Record 32 of Set 14 | jiuquan
# Processing Record 33 of Set 14 | prince rupert
# Processing Record 34 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 14 | krivopolyanye
# City not found. Skipping...
# Processing Record 36 of Set 14 | qarqin
# Processing Record 37 of Set 14 | skibotn
# Processing Record 38 of Set 14 | verkhoyansk
# Processing Record 39 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 40 of Set 14 | banepa
# Processing Record 41 of Set 14 | cururupu
# Processing Record 42 of Set 14 | khash
# Processing Record 43 of Set 14 | thinadhoo
# Processing Record 44 of Set 14 | pacific grove
# Processing Record 45 of Set 14 | ares
# Processing Record 46 of Set 14 | labuhan
# Processing Record 47 of Set 14 | baykit
# Processing Record 48 of Set 14 | skibbereen
# Processing Record 49 of Set 14 | monzon
# Processing Record 50 of Set 14 | shkotovo-26
# City not found. Skipping...
# Processing Record 1 of Set 15 | ambilobe
# Processing Record 2 of Set 15 | mehran
# Processing Record 3 of Set 15 | villa carlos paz
# Processing Record 4 of Set 15 | cairns
# Processing Record 5 of Set 15 | reinosa
# Processing Record 6 of Set 15 | xinmin
# Processing Record 7 of Set 15 | spokane
# Processing Record 8 of Set 15 | puerto del rosario
# Processing Record 9 of Set 15 | ahuimanu
# Processing Record 10 of Set 15 | saint-pierre
# Processing Record 11 of Set 15 | mount hagen
# Processing Record 12 of Set 15 | san patricio
# Processing Record 13 of Set 15 | san jose de guanipa
# Processing Record 14 of Set 15 | tahta
# Processing Record 15 of Set 15 | matara
# Processing Record 16 of Set 15 | kattivakkam
# Processing Record 17 of Set 15 | mangan
# Processing Record 18 of Set 15 | pemangkat
# Processing Record 19 of Set 15 | agadir
# Processing Record 20 of Set 15 | vavuniya
# Processing Record 21 of Set 15 | shwebo
# Processing Record 22 of Set 15 | balgazyn
# Processing Record 23 of Set 15 | camacha
# Processing Record 24 of Set 15 | lodi
# Processing Record 25 of Set 15 | vianden
# Processing Record 26 of Set 15 | charagua
# Processing Record 27 of Set 15 | kysyl-syr
# Processing Record 28 of Set 15 | fuyang
# Processing Record 29 of Set 15 | baiyin
# Processing Record 30 of Set 15 | novyy urengoy
# Processing Record 31 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 32 of Set 15 | kushiro
# Processing Record 33 of Set 15 | tatawin
# Processing Record 34 of Set 15 | jieshi
# Processing Record 35 of Set 15 | tazovskiy
# Processing Record 36 of Set 15 | ardesen
# Processing Record 37 of Set 15 | praia da vitoria
# Processing Record 38 of Set 15 | hundested
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': 11.8667, 'lat': 55.9667},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 52.25,
#   'feels_like': 51.46,
#   'temp_min': 46.69,
#   'temp_max': 53.01,
#   'pressure': 1018,
#   'humidity': 91},
#  'visibility': 10000,
#  'wind': {'speed': 5.01, 'deg': 133},
#  'clouds': {'all': 100},
#  'dt': 1664843970,
#  'sys': {'type': 2,
#   'id': 2007058,
#   'country': 'DK',
#   'sunrise': 1664860852,
#   'sunset': 1664901693},
#  'timezone': 7200,
#  'id': 2619650,
#  'name': 'Hundested',
#  'cod': 200}

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 681

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
# Out:
#    latitud  longitude  temperature  humidity  cloudiness  wind_speed country  \
# 0 -34.5322    20.0403        50.61        89           0        6.69      ZA
# 1  20.8947  -156.4700        82.42        81          75       17.27      US
# 2  60.9500    25.9333        41.85        69         100       12.64      FI
# 3  18.0858   -15.9785        82.33        59          38        7.52      MR
# 4  22.9333    57.5333        75.92        66          23        2.35      OM
# 5  41.3712   -73.4140        50.65        84         100        6.91      US
# 6  50.6789   156.1250        52.66        77          97       12.08      RU
# 7  -8.9266   125.4092        68.23        77          99        1.48      TL
# 8  59.7035    30.7861        48.09        94         100        8.14      RU
# 9  53.9202   102.0442        29.16        93         100        2.91      RU
#
#        description             city
# 0        clear sky       Bredasdorp
# 1       light rain          Kahului
# 2  overcast clouds          Nastola
# 3       light rain       Nouakchott
# 4       few clouds            Nizwá
# 5       light rain           Bethel
# 6  overcast clouds  Severo-Kuril'sk
# 7  overcast clouds            Airai
# 8  overcast clouds       Nikolskoye
# 9       light snow             Zima

# %%
# Display sample data
city_data_df.head(10)
# Out:
#    latitud  longitude  temperature  humidity  cloudiness  wind_speed country  \
# 0 -34.5322    20.0403        50.61        89           0        6.69      ZA
# 1  20.8947  -156.4700        82.42        81          75       17.27      US
# 2  60.9500    25.9333        41.85        69         100       12.64      FI
# 3  18.0858   -15.9785        82.33        59          38        7.52      MR
# 4  22.9333    57.5333        75.92        66          23        2.35      OM
# 5  41.3712   -73.4140        50.65        84         100        6.91      US
# 6  50.6789   156.1250        52.66        77          97       12.08      RU
# 7  -8.9266   125.4092        68.23        77          99        1.48      TL
# 8  59.7035    30.7861        48.09        94         100        8.14      RU
# 9  53.9202   102.0442        29.16        93         100        2.91      RU
#
#        description             city
# 0        clear sky       Bredasdorp
# 1       light rain          Kahului
# 2  overcast clouds          Nastola
# 3       light rain       Nouakchott
# 4       few clouds            Nizwá
# 5       light rain           Bethel
# 6  overcast clouds  Severo-Kuril'sk
# 7  overcast clouds            Airai
# 8  overcast clouds       Nikolskoye
# 9       light snow             Zima

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['latitud', 'longitude', 'temperature', 'humidity', 'cloudiness',
#        'wind_speed', 'country', 'description', 'city'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
