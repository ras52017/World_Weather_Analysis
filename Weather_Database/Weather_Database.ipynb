# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

type(lat_lngs)
# Out:
# zip

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print(coordinates)
# Out:
# [(70.72794995018344, -179.4431425044478), (40.940619023967855, -16.910769250727867), (-38.774615519954324, -44.16773665990502), (-81.43626244268741, 116.2872125594111), (-55.28322376425742, -128.96991383093263), (-23.572789891245762, 162.77851837703048), (-34.28113362788716, -8.068460758314814), (-45.62544895662529, 30.463011905798624), (-38.34371444989064, 70.6994342874917), (16.691039783029566, -97.53054900638324), (-16.920090487006163, -46.74187138613195), (10.937584113886302, -69.88136588849952), (3.789650488375912, 71.46548380743286), (14.265950836686457, -100.18608914238958), (-58.13643637511441, 71.05723261352628), (-46.01778456219312, -166.40889768393345), (35.933982082119144, -165.67025743784947), (22.510902558213317, 25.951740271804965), (-59.10886218592637, -106.68414186511752), (70.04534814132225, -53.897714801541525), (43.78082951181324, -53.42805538954657), (-25.29104521608683, 75.48274244857316), (48.12135499901609, -127.25865426458915), (80.48362664940711, -76.95616640220446), (-71.60148951955881, 151.4173352231391), (-16.11311344922906, -91.67517719809781), (43.41616414294313, 138.60948055116972), (-68.83493008256274, 33.385952856107), (57.60877587499303, 172.43815999215911), (-82.85947596702135, 173.3055298521519), (-21.261551063045175, -15.042851154882271), (2.010174289710946, -168.15065768980463), (81.02424620124194, -16.34273495072523), (-71.71475866585173, 92.78469454644295), (-10.602523562799306, -99.70442585908434), (67.05491023059622, 155.95423143731358), (-83.4200586323852, -78.4842763168477), (-88.73251492828282, -7.506748247754615), (23.030261936112936, -57.649079727720675), (-6.527187846790682, -86.19844168617603), (-55.04016364170172, -87.01786116073752), (-54.133855555443134, -149.0915827514871), (-51.55983505732877, -35.19330929175874), (-57.886683033436476, 160.24379688802725), (-40.7007112976026, 167.6303111767026), (0.6245979192123343, -154.2642761676287), (68.6120495581199, 152.77209805906972), (9.123051777131494, -20.02911619439007), (-54.24859453849969, 151.14630362492375), (76.14521042409518, 136.67858976029754), (-84.10229567119964, 11.57306243337726), (-5.9171401661309915, 92.3678497205824), (15.286953032740868, -30.457352577111806), (-23.826181451307676, -162.6308048315482), (71.40008957754284, -45.666549475696684), (27.661763681478547, -166.18132044122848), (5.824168239599857, 82.40666658058632), (5.640715948358292, -20.1321075249856), (45.112793299947725, 37.679050909501626), (-81.85294725608289, 115.59835618069377), (-24.59490783984387, -91.04247121212786), (-63.50011896035198, 91.984442897122), (-30.33125344116246, -167.16770392673683), (-67.22403064179014, -174.32040391402003), (-86.65800702564104, 93.75194053079105), (81.24315900350629, 66.25999408544541), (-63.0379480293777, 118.964187250814), (-83.65678127303605, 113.64858235572581), (-20.913107809810768, -100.14229366860692), (-64.46294332862863, -91.91648510980536), (-4.1804418418069105, -110.9941840126907), (5.072294568951904, 144.98613621591636), (-48.85804267536434, -112.99142739526592), (-75.05261280505556, 93.49670990830293), (41.094461308514695, -29.36357405647456), (7.301406718052945, -133.90718792209918), (33.37437288079134, 100.99670243123717), (-55.09063559889013, -150.97283090675248), (-39.23784084018681, -20.17839496318902), (60.748902717126185, -158.95149853084115), (74.85321797125707, 173.99139513069127), (-4.698283877855303, -1.2649025325471541), (-59.28618461030602, 175.24597066677512), (-35.28466145912417, 157.60615831004992), (46.53000429641543, -2.1454759531480647), (-21.884048531408496, 99.69981151527975), (65.99007681384705, -6.529559178393981), (68.20378216733971, 20.303049716861437), (-28.896759158334113, 134.61213082716256), (-70.44440561112175, 38.687436828198116), (-67.16573999151088, -142.04372745627248), (-55.32561573224948, 52.992095052003265), (-53.32758887333769, -44.67860094095897), (-40.598922124527576, -117.93872446917595), (21.704804975022654, 110.49958565200512), (-69.4520792214085, -58.131 ...

# %%
coordinates[0][1]
# Out:
# -179.4431425044478

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE
cities = []
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 730

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
# YOUR CODE HERE
url= "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
                
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE  
        lat=city_weather["coord"]["lat"]
        lon=city_weather["coord"]["lon"]
        max_temp=city_weather["main"]["temp_max"]
        humidity=city_weather["main"]["humidity"]
        cloudiness=city_weather["clouds"]["all"]
        wind=city_weather["wind"]["speed"]
        country=city_weather["sys"]["country"]
        description=city_weather["weather"][0]["description"]
        city =city_weather["name"]
        # Append the city information into the city_data list
        # YOUR CODE HERE,
        
        city_data.append({"latitud": lat,
                         "longitude": lon,
                         "temperature": max_temp,
                         "humidity":humidity,
                         "cloudiness":cloudiness,
                         "wind_speed": wind,
                         "country":country,
                         "description":description,
                         "city":city})
            # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 1 | peniche
# Processing Record 3 of Set 1 | rio grande
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | pouembout
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | mahebourg
# Processing Record 10 of Set 1 | zacatepec
# Processing Record 11 of Set 1 | paracatu
# Processing Record 12 of Set 1 | coro
# Processing Record 13 of Set 1 | mahibadhoo
# Processing Record 14 of Set 1 | acapulco
# Processing Record 15 of Set 1 | saint-philippe
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | tahta
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | aasiaat
# Processing Record 21 of Set 1 | bay roberts
# Processing Record 22 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 1 | ucluelet
# Processing Record 24 of Set 1 | qaanaaq
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | huarmey
# Processing Record 27 of Set 1 | iwanai
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | srednekolymsk
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | codrington
# Processing Record 39 of Set 1 | paita
# Processing Record 40 of Set 1 | mataura
# Processing Record 41 of Set 1 | chuy
# Processing Record 42 of Set 1 | hokitika
# Processing Record 43 of Set 1 | faanui
# Processing Record 44 of Set 1 | bubaque
# Processing Record 45 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 1 | padang
# Processing Record 47 of Set 1 | porto novo
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | hambantota
# Processing Record 50 of Set 1 | varenikovskaya
# Processing Record 1 of Set 2 | pisco
# Processing Record 2 of Set 2 | alofi
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 2 | lorengau
# Processing Record 6 of Set 2 | lagoa
# Processing Record 7 of Set 2 | atuona
# Processing Record 8 of Set 2 | linxia
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | komsomolskiy
# Processing Record 12 of Set 2 | takoradi
# Processing Record 13 of Set 2 | kaitangata
# Processing Record 14 of Set 2 | nelson bay
# Processing Record 15 of Set 2 | challans
# Processing Record 16 of Set 2 | carnarvon
# Processing Record 17 of Set 2 | klaksvik
# Processing Record 18 of Set 2 | kiruna
# Processing Record 19 of Set 2 | flinders
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | mar del plata
# Processing Record 22 of Set 2 | huazhou
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | birao
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | bumba
# Processing Record 29 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 2 | nanortalik
# Processing Record 31 of Set 2 | kavieng
# Processing Record 32 of Set 2 | jega
# Processing Record 33 of Set 2 | guerrero negro
# Processing Record 34 of Set 2 | najran
# Processing Record 35 of Set 2 | ulukulevo
# Processing Record 36 of Set 2 | burnie
# Processing Record 37 of Set 2 | lucea
# Processing Record 38 of Set 2 | cape town
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | kalmunai
# Processing Record 43 of Set 2 | yagodnoye
# Processing Record 44 of Set 2 | karratha
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | dikson
# Processing Record 47 of Set 2 | sao joao da barra
# Processing Record 48 of Set 2 | kapiri mposhi
# Processing Record 49 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 50 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 3 | sisimiut
# Processing Record 2 of Set 3 | vila franca do campo
# Processing Record 3 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 3 | port hedland
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | glen allen
# Processing Record 7 of Set 3 | champerico
# Processing Record 8 of Set 3 | qasigiannguit
# Processing Record 9 of Set 3 | lebu
# Processing Record 10 of Set 3 | apricena
# Processing Record 11 of Set 3 | vereeniging
# Processing Record 12 of Set 3 | quilmana
# Processing Record 13 of Set 3 | saint george
# Processing Record 14 of Set 3 | tezu
# Processing Record 15 of Set 3 | atar
# Processing Record 16 of Set 3 | kalemie
# Processing Record 17 of Set 3 | uniao da victoria
# City not found. Skipping...
# Processing Record 18 of Set 3 | provideniya
# Processing Record 19 of Set 3 | bathsheba
# Processing Record 20 of Set 3 | asosa
# Processing Record 21 of Set 3 | champasak
# Processing Record 22 of Set 3 | qarqin
# Processing Record 23 of Set 3 | leningradskiy
# Processing Record 24 of Set 3 | san cristobal
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 3 | san quintin
# Processing Record 28 of Set 3 | bredasdorp
# Processing Record 29 of Set 3 | icod de los vinos
# Processing Record 30 of Set 3 | portage
# Processing Record 31 of Set 3 | tura
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | warmbad
# Processing Record 34 of Set 3 | caravelas
# Processing Record 35 of Set 3 | khatanga
# Processing Record 36 of Set 3 | chokurdakh
# Processing Record 37 of Set 3 | sebinkarahisar
# Processing Record 38 of Set 3 | sorland
# Processing Record 39 of Set 3 | litoral del san juan
# City not found. Skipping...
# Processing Record 40 of Set 3 | margate
# Processing Record 41 of Set 3 | iqaluit
# Processing Record 42 of Set 3 | westport
# Processing Record 43 of Set 3 | ostrovnoy
# Processing Record 44 of Set 3 | xiaoweizhai
# Processing Record 45 of Set 3 | kodiak
# Processing Record 46 of Set 3 | richards bay
# Processing Record 47 of Set 3 | gushikawa
# Processing Record 48 of Set 3 | chinhoyi
# Processing Record 49 of Set 3 | dangriga
# Processing Record 50 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 1 of Set 4 | hithadhoo
# Processing Record 2 of Set 4 | saskylakh
# Processing Record 3 of Set 4 | cabo san lucas
# Processing Record 4 of Set 4 | sambava
# Processing Record 5 of Set 4 | pozo colorado
# Processing Record 6 of Set 4 | independencia
# Processing Record 7 of Set 4 | manokwari
# Processing Record 8 of Set 4 | nemuro
# Processing Record 9 of Set 4 | baijiantan
# Processing Record 10 of Set 4 | obluche
# City not found. Skipping...
# Processing Record 11 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 4 | tasiilaq
# Processing Record 13 of Set 4 | bac lieu
# Processing Record 14 of Set 4 | bambous virieux
# Processing Record 15 of Set 4 | hastings
# Processing Record 16 of Set 4 | olafsvik
# Processing Record 17 of Set 4 | cherskiy
# Processing Record 18 of Set 4 | roebourne
# Processing Record 19 of Set 4 | coquimbo
# Processing Record 20 of Set 4 | gigmoto
# Processing Record 21 of Set 4 | hay river
# Processing Record 22 of Set 4 | grootfontein
# Processing Record 23 of Set 4 | vila velha
# Processing Record 24 of Set 4 | sabang
# Processing Record 25 of Set 4 | tirumullaivasal
# Processing Record 26 of Set 4 | souillac
# Processing Record 27 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 4 | ariquemes
# Processing Record 29 of Set 4 | tuktoyaktuk
# Processing Record 30 of Set 4 | nome
# Processing Record 31 of Set 4 | yumen
# Processing Record 32 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 33 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 35 of Set 4 | yeppoon
# Processing Record 36 of Set 4 | zhigansk
# Processing Record 37 of Set 4 | asfi
# Processing Record 38 of Set 4 | san rafael
# Processing Record 39 of Set 4 | altagracia de orituco
# Processing Record 40 of Set 4 | prado
# Processing Record 41 of Set 4 | altay
# Processing Record 42 of Set 4 | brae
# Processing Record 43 of Set 4 | ossora
# Processing Record 44 of Set 4 | poum
# Processing Record 45 of Set 4 | krasnoselkup
# Processing Record 46 of Set 4 | salalah
# Processing Record 47 of Set 4 | tamworth
# Processing Record 48 of Set 4 | newport
# Processing Record 49 of Set 4 | amot
# Processing Record 50 of Set 4 | biltine
# Processing Record 1 of Set 5 | touros
# Processing Record 2 of Set 5 | port-gentil
# Processing Record 3 of Set 5 | glubokoe
# City not found. Skipping...
# Processing Record 4 of Set 5 | jizan
# Processing Record 5 of Set 5 | catamarca
# Processing Record 6 of Set 5 | severo-kurilsk
# Processing Record 7 of Set 5 | aksu
# Processing Record 8 of Set 5 | ponta delgada
# Processing Record 9 of Set 5 | hofn
# Processing Record 10 of Set 5 | gundorovskiy
# Processing Record 11 of Set 5 | port washington
# Processing Record 12 of Set 5 | georgetown
# Processing Record 13 of Set 5 | leh
# Processing Record 14 of Set 5 | zhangye
# Processing Record 15 of Set 5 | finschhafen
# Processing Record 16 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 5 | longyan
# Processing Record 18 of Set 5 | beni suef
# Processing Record 19 of Set 5 | portland
# Processing Record 20 of Set 5 | vanavara
# Processing Record 21 of Set 5 | tilichiki
# Processing Record 22 of Set 5 | lompoc
# Processing Record 23 of Set 5 | kalulushi
# Processing Record 24 of Set 5 | tipitapa
# Processing Record 25 of Set 5 | doha
# Processing Record 26 of Set 5 | hobyo
# Processing Record 27 of Set 5 | eldikan
# City not found. Skipping...
# Processing Record 28 of Set 5 | lavrentiya
# Processing Record 29 of Set 5 | mingshui
# Processing Record 30 of Set 5 | tarbert
# Processing Record 31 of Set 5 | nador
# Processing Record 32 of Set 5 | sao filipe
# Processing Record 33 of Set 5 | ankpa
# Processing Record 34 of Set 5 | sassandra
# Processing Record 35 of Set 5 | manakara
# Processing Record 36 of Set 5 | jalu
# Processing Record 37 of Set 5 | carballo
# Processing Record 38 of Set 5 | san jose de rio tinto
# Processing Record 39 of Set 5 | talnakh
# Processing Record 40 of Set 5 | nanchong
# Processing Record 41 of Set 5 | goderich
# Processing Record 42 of Set 5 | puerto escondido
# Processing Record 43 of Set 5 | villa alemana
# Processing Record 44 of Set 5 | mantua
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | kahului
# Processing Record 47 of Set 5 | avera
# Processing Record 48 of Set 5 | pacific grove
# Processing Record 49 of Set 5 | upernavik
# Processing Record 50 of Set 5 | haines junction
# Processing Record 1 of Set 6 | krasnoyarskiy
# Processing Record 2 of Set 6 | eureka
# Processing Record 3 of Set 6 | marawi
# Processing Record 4 of Set 6 | rawson
# Processing Record 5 of Set 6 | ponta do sol
# Processing Record 6 of Set 6 | general roca
# Processing Record 7 of Set 6 | bolshaya dzhalga
# Processing Record 8 of Set 6 | rondonopolis
# Processing Record 9 of Set 6 | port shepstone
# Processing Record 10 of Set 6 | airai
# Processing Record 11 of Set 6 | carutapera
# Processing Record 12 of Set 6 | aldan
# Processing Record 13 of Set 6 | calvinia
# Processing Record 14 of Set 6 | puerto suarez
# Processing Record 15 of Set 6 | opuwo
# Processing Record 16 of Set 6 | mbumi
# Processing Record 17 of Set 6 | erdenet
# Processing Record 18 of Set 6 | esperance
# Processing Record 19 of Set 6 | tomaszow mazowiecki
# Processing Record 20 of Set 6 | blagoyevo
# Processing Record 21 of Set 6 | castro
# Processing Record 22 of Set 6 | cabedelo
# Processing Record 23 of Set 6 | tevaitoa
# Processing Record 24 of Set 6 | tarakan
# Processing Record 25 of Set 6 | katsuura
# Processing Record 26 of Set 6 | henties bay
# Processing Record 27 of Set 6 | gueret
# Processing Record 28 of Set 6 | hasaki
# Processing Record 29 of Set 6 | san patricio
# Processing Record 30 of Set 6 | aleysk
# Processing Record 31 of Set 6 | geraldton
# Processing Record 32 of Set 6 | thompson
# Processing Record 33 of Set 6 | mayumba
# Processing Record 34 of Set 6 | mahaicony
# City not found. Skipping...
# Processing Record 35 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 36 of Set 6 | blythe
# Processing Record 37 of Set 6 | narsaq
# Processing Record 38 of Set 6 | yaring
# Processing Record 39 of Set 6 | vetluzhskiy
# Processing Record 40 of Set 6 | swift current
# Processing Record 41 of Set 6 | ust-tsilma
# Processing Record 42 of Set 6 | yerbogachen
# Processing Record 43 of Set 6 | gat
# Processing Record 44 of Set 6 | jumla
# Processing Record 45 of Set 6 | torbay
# Processing Record 46 of Set 6 | jaru
# Processing Record 47 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 48 of Set 6 | senno
# Processing Record 49 of Set 6 | pizhma
# Processing Record 50 of Set 6 | gari
# Processing Record 1 of Set 7 | ihosy
# Processing Record 2 of Set 7 | husavik
# Processing Record 3 of Set 7 | isangel
# Processing Record 4 of Set 7 | madimba
# Processing Record 5 of Set 7 | fairfield
# Processing Record 6 of Set 7 | tungor
# Processing Record 7 of Set 7 | gorontalo
# Processing Record 8 of Set 7 | yamasaki
# Processing Record 9 of Set 7 | grimari
# City not found. Skipping...
# Processing Record 10 of Set 7 | bilibino
# Processing Record 11 of Set 7 | tra vinh
# Processing Record 12 of Set 7 | inhambane
# Processing Record 13 of Set 7 | hope
# Processing Record 14 of Set 7 | bria
# Processing Record 15 of Set 7 | san juan del sur
# Processing Record 16 of Set 7 | ciras
# City not found. Skipping...
# Processing Record 17 of Set 7 | plettenberg bay
# Processing Record 18 of Set 7 | la libertad
# Processing Record 19 of Set 7 | pangnirtung
# Processing Record 20 of Set 7 | miri
# Processing Record 21 of Set 7 | sinnamary
# Processing Record 22 of Set 7 | luanda
# Processing Record 23 of Set 7 | micheweni
# Processing Record 24 of Set 7 | marsa matruh
# Processing Record 25 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 26 of Set 7 | ahipara
# Processing Record 27 of Set 7 | grand gaube
# Processing Record 28 of Set 7 | bikaner
# Processing Record 29 of Set 7 | south venice
# Processing Record 30 of Set 7 | saint-francois
# Processing Record 31 of Set 7 | la asuncion
# Processing Record 32 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 7 | kachug
# Processing Record 34 of Set 7 | znamenskoye
# Processing Record 35 of Set 7 | manta
# Processing Record 36 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 7 | pevek
# Processing Record 38 of Set 7 | sherbakul
# Processing Record 39 of Set 7 | hojai
# Processing Record 40 of Set 7 | kruisfontein
# Processing Record 41 of Set 7 | victoria
# Processing Record 42 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 7 | kieta
# Processing Record 44 of Set 7 | acajutla
# Processing Record 45 of Set 7 | tubuala
# Processing Record 46 of Set 7 | swan hill
# Processing Record 47 of Set 7 | praia
# Processing Record 48 of Set 7 | jinchang
# Processing Record 49 of Set 7 | sivaki
# Processing Record 50 of Set 7 | khash
# Processing Record 1 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 8 | hualmay
# Processing Record 3 of Set 8 | kinablangan
# Processing Record 4 of Set 8 | indramayu
# Processing Record 5 of Set 8 | sumbe
# Processing Record 6 of Set 8 | los llanos de aridane
# Processing Record 7 of Set 8 | la ronge
# Processing Record 8 of Set 8 | leshukonskoye
# Processing Record 9 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 10 of Set 8 | la paz
# Processing Record 11 of Set 8 | te anau
# Processing Record 12 of Set 8 | monrovia
# Processing Record 13 of Set 8 | port hardy
# Processing Record 14 of Set 8 | talaya
# Processing Record 15 of Set 8 | champoton
# Processing Record 16 of Set 8 | kristiansund
# Processing Record 17 of Set 8 | half moon bay
# Processing Record 18 of Set 8 | broken hill
# Processing Record 19 of Set 8 | tuatapere
# Processing Record 20 of Set 8 | kizilskoye
# Processing Record 21 of Set 8 | axim
# Processing Record 22 of Set 8 | srandakan
# Processing Record 23 of Set 8 | kanonji
# Processing Record 24 of Set 8 | yulara
# Processing Record 25 of Set 8 | varzea grande
# Processing Record 26 of Set 8 | rimini
# Processing Record 27 of Set 8 | morganton
# Processing Record 28 of Set 8 | hellvik
# Processing Record 29 of Set 8 | batagay-alyta
# Processing Record 30 of Set 8 | coulihaut
# City not found. Skipping...
# Processing Record 31 of Set 8 | vigrestad
# Processing Record 32 of Set 8 | fortuna
# Processing Record 33 of Set 8 | zacualtipan
# Processing Record 34 of Set 8 | pueblo nuevo
# Processing Record 35 of Set 8 | atambua
# Processing Record 36 of Set 8 | sergeyevka
# Processing Record 37 of Set 8 | trincomalee
# Processing Record 38 of Set 8 | grindavik
# Processing Record 39 of Set 8 | chapais
# Processing Record 40 of Set 8 | panzhihua
# Processing Record 41 of Set 8 | anloga
# Processing Record 42 of Set 8 | tsiroanomandidy
# Processing Record 43 of Set 8 | saldanha
# Processing Record 44 of Set 8 | toora-khem
# Processing Record 45 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 46 of Set 8 | piedras amarillas
# City not found. Skipping...
# Processing Record 47 of Set 8 | tatarsk
# Processing Record 48 of Set 8 | posse
# Processing Record 49 of Set 8 | malanje
# Processing Record 50 of Set 8 | algarrobo
# Processing Record 1 of Set 9 | hami
# Processing Record 2 of Set 9 | asau
# Processing Record 3 of Set 9 | port blair
# Processing Record 4 of Set 9 | kijang
# Processing Record 5 of Set 9 | antofagasta
# Processing Record 6 of Set 9 | byron bay
# Processing Record 7 of Set 9 | sungaipenuh
# Processing Record 8 of Set 9 | belyy yar
# Processing Record 9 of Set 9 | santa cruz
# Processing Record 10 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 9 | plouzane
# Processing Record 12 of Set 9 | svetlogorsk
# Processing Record 13 of Set 9 | lala
# Processing Record 14 of Set 9 | okha
# Processing Record 15 of Set 9 | killam
# Processing Record 16 of Set 9 | east london
# Processing Record 17 of Set 9 | kirakira
# Processing Record 18 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 19 of Set 9 | vardo
# Processing Record 20 of Set 9 | cedar city
# Processing Record 21 of Set 9 | nalut
# Processing Record 22 of Set 9 | hervey bay
# Processing Record 23 of Set 9 | cockburn town
# Processing Record 24 of Set 9 | sehithwa
# Processing Record 25 of Set 9 | bengkulu
# Processing Record 26 of Set 9 | horqueta
# Processing Record 27 of Set 9 | cao bang
# Processing Record 28 of Set 9 | mpulungu
# Processing Record 29 of Set 9 | kongolo
# Processing Record 30 of Set 9 | japura
# Processing Record 31 of Set 9 | porosozero
# Processing Record 32 of Set 9 | edea
# Processing Record 33 of Set 9 | hamilton
# Processing Record 34 of Set 9 | kurilsk
# Processing Record 35 of Set 9 | omboue
# Processing Record 36 of Set 9 | urumqi
# Processing Record 37 of Set 9 | wloclawek
# Processing Record 38 of Set 9 | camacha
# Processing Record 39 of Set 9 | kabinda
# Processing Record 40 of Set 9 | constitucion
# Processing Record 41 of Set 9 | soe
# Processing Record 42 of Set 9 | acari
# Processing Record 43 of Set 9 | dali
# Processing Record 44 of Set 9 | beringovskiy
# Processing Record 45 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 46 of Set 9 | pilot butte
# Processing Record 47 of Set 9 | martin
# Processing Record 48 of Set 9 | funadhoo
# Processing Record 49 of Set 9 | ambulu
# Processing Record 50 of Set 9 | gedo
# Processing Record 1 of Set 10 | jaciara
# Processing Record 2 of Set 10 | ulladulla
# Processing Record 3 of Set 10 | sao gabriel da cachoeira
# Processing Record 4 of Set 10 | mizdah
# Processing Record 5 of Set 10 | qandala
# Processing Record 6 of Set 10 | alice springs
# Processing Record 7 of Set 10 | san policarpo
# Processing Record 8 of Set 10 | rundu
# Processing Record 9 of Set 10 | sao geraldo do araguaia
# Processing Record 10 of Set 10 | college
# Processing Record 11 of Set 10 | san lazaro
# Processing Record 12 of Set 10 | aklavik
# Processing Record 13 of Set 10 | rassvet
# Processing Record 14 of Set 10 | cairns
# Processing Record 15 of Set 10 | novobirilyussy
# Processing Record 16 of Set 10 | matara
# Processing Record 17 of Set 10 | wellington
# Processing Record 18 of Set 10 | bereznik
# Processing Record 19 of Set 10 | beloha
# Processing Record 20 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 10 | bintulu
# Processing Record 22 of Set 10 | elat
# Processing Record 23 of Set 10 | umm bab
# Processing Record 24 of Set 10 | tshikapa
# Processing Record 25 of Set 10 | sinnar
# Processing Record 26 of Set 10 | bafq
# Processing Record 27 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 10 | maniitsoq
# Processing Record 29 of Set 10 | goma
# Processing Record 30 of Set 10 | san pedro
# Processing Record 31 of Set 10 | xinye
# Processing Record 32 of Set 10 | malakal
# Processing Record 33 of Set 10 | raga
# Processing Record 34 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 10 | zaysan
# Processing Record 36 of Set 10 | alibag
# Processing Record 37 of Set 10 | ciudad ojeda
# Processing Record 38 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 10 | kedrovyy
# Processing Record 40 of Set 10 | yuksekova
# Processing Record 41 of Set 10 | fort nelson
# Processing Record 42 of Set 10 | vila
# Processing Record 43 of Set 10 | rocha
# Processing Record 44 of Set 10 | kitob
# Processing Record 45 of Set 10 | roald
# Processing Record 46 of Set 10 | namibe
# Processing Record 47 of Set 10 | douglas
# Processing Record 48 of Set 10 | makakilo city
# Processing Record 49 of Set 10 | clyde river
# Processing Record 50 of Set 10 | coxim
# Processing Record 1 of Set 11 | petatlan
# Processing Record 2 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 3 of Set 11 | pontes e lacerda
# Processing Record 4 of Set 11 | baykit
# Processing Record 5 of Set 11 | pulaski
# Processing Record 6 of Set 11 | cascais
# Processing Record 7 of Set 11 | doka
# Processing Record 8 of Set 11 | wewak
# Processing Record 9 of Set 11 | valdivia
# Processing Record 10 of Set 11 | bonavista
# Processing Record 11 of Set 11 | san jose
# Processing Record 12 of Set 11 | talara
# Processing Record 13 of Set 11 | sitka
# Processing Record 14 of Set 11 | ampanihy
# Processing Record 15 of Set 11 | mudyuga
# City not found. Skipping...
# Processing Record 16 of Set 11 | gravdal
# Processing Record 17 of Set 11 | cuamba
# Processing Record 18 of Set 11 | tutoia
# Processing Record 19 of Set 11 | port moresby
# Processing Record 20 of Set 11 | sobolevo
# Processing Record 21 of Set 11 | baruun-urt
# Processing Record 22 of Set 11 | cavalcante
# Processing Record 23 of Set 11 | port macquarie
# Processing Record 24 of Set 11 | alyangula
# Processing Record 25 of Set 11 | vilhena
# Processing Record 26 of Set 11 | ulaangom
# Processing Record 27 of Set 11 | alta floresta
# Processing Record 28 of Set 11 | naifaru
# Processing Record 29 of Set 11 | krasnoarmeysk
# Processing Record 30 of Set 11 | langxiang
# Processing Record 31 of Set 11 | berdigestyakh
# Processing Record 32 of Set 11 | vestmanna
# Processing Record 33 of Set 11 | spruce grove
# Processing Record 34 of Set 11 | lasa
# Processing Record 35 of Set 11 | puerto baquerizo moreno
# Processing Record 36 of Set 11 | hovd
# Processing Record 37 of Set 11 | port hawkesbury
# Processing Record 38 of Set 11 | hondo
# Processing Record 39 of Set 11 | balotra
# Processing Record 40 of Set 11 | cayenne
# Processing Record 41 of Set 11 | shimoda
# Processing Record 42 of Set 11 | washington
# Processing Record 43 of Set 11 | parfenyevo
# Processing Record 44 of Set 11 | fukue
# Processing Record 45 of Set 11 | kaolinovo
# Processing Record 46 of Set 11 | dunedin
# Processing Record 47 of Set 11 | yuzhno-kurilsk
# Processing Record 48 of Set 11 | san vicente
# Processing Record 49 of Set 11 | santo antonio do leverger
# Processing Record 50 of Set 11 | havelock
# Processing Record 1 of Set 12 | meadow lake
# Processing Record 2 of Set 12 | hvide sande
# Processing Record 3 of Set 12 | qabaqcol
# Processing Record 4 of Set 12 | vikhorevka
# Processing Record 5 of Set 12 | mount gambier
# Processing Record 6 of Set 12 | himora
# City not found. Skipping...
# Processing Record 7 of Set 12 | wakkanai
# Processing Record 8 of Set 12 | shingu
# Processing Record 9 of Set 12 | araouane
# Processing Record 10 of Set 12 | kanpur
# Processing Record 11 of Set 12 | sorong
# Processing Record 12 of Set 12 | imeni poliny osipenko
# Processing Record 13 of Set 12 | ferme-neuve
# Processing Record 14 of Set 12 | nakhon si thammarat
# Processing Record 15 of Set 12 | banda aceh
# Processing Record 16 of Set 12 | akyab
# Processing Record 17 of Set 12 | ovsyanka
# Processing Record 18 of Set 12 | boke
# Processing Record 19 of Set 12 | silver city
# Processing Record 20 of Set 12 | paamiut
# Processing Record 21 of Set 12 | meulaboh
# Processing Record 22 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 23 of Set 12 | kaseda
# Processing Record 24 of Set 12 | ostersund
# Processing Record 25 of Set 12 | dubuque
# Processing Record 26 of Set 12 | berlevag
# Processing Record 27 of Set 12 | grand island
# Processing Record 28 of Set 12 | mmabatho
# Processing Record 29 of Set 12 | bauchi
# Processing Record 30 of Set 12 | maraa
# Processing Record 31 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 32 of Set 12 | mandalgovi
# Processing Record 33 of Set 12 | ancud
# Processing Record 34 of Set 12 | manacapuru
# Processing Record 35 of Set 12 | middelburg
# Processing Record 36 of Set 12 | andenes
# Processing Record 37 of Set 12 | strezhevoy
# Processing Record 38 of Set 12 | vestmannaeyjar
# Processing Record 39 of Set 12 | kiama
# Processing Record 40 of Set 12 | neuquen
# Processing Record 41 of Set 12 | ormara
# Processing Record 42 of Set 12 | loreto
# Processing Record 43 of Set 12 | muros
# Processing Record 44 of Set 12 | alvorada
# Processing Record 45 of Set 12 | rosita
# Processing Record 46 of Set 12 | nuevo progreso
# Processing Record 47 of Set 12 | nyurba
# Processing Record 48 of Set 12 | guaramirim
# Processing Record 49 of Set 12 | englewood
# Processing Record 50 of Set 12 | ixtapa
# Processing Record 1 of Set 13 | seoul
# Processing Record 2 of Set 13 | bailen
# Processing Record 3 of Set 13 | surt
# Processing Record 4 of Set 13 | anadyr
# Processing Record 5 of Set 13 | dingle
# Processing Record 6 of Set 13 | vanimo
# Processing Record 7 of Set 13 | bairiki
# Processing Record 8 of Set 13 | villa carlos paz
# Processing Record 9 of Set 13 | boueni
# Processing Record 10 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 11 of Set 13 | coihaique
# Processing Record 12 of Set 13 | arawa
# Processing Record 13 of Set 13 | bama
# Processing Record 14 of Set 13 | agadez
# Processing Record 15 of Set 13 | balagansk
# Processing Record 16 of Set 13 | fuente de oro
# Processing Record 17 of Set 13 | mnogovershinnyy
# Processing Record 18 of Set 13 | sioux lookout
# Processing Record 19 of Set 13 | kavaratti
# Processing Record 20 of Set 13 | damara
# Processing Record 21 of Set 13 | korhogo
# Processing Record 22 of Set 13 | minas
# Processing Record 23 of Set 13 | vajszlo
# Processing Record 24 of Set 13 | chicama
# Processing Record 25 of Set 13 | ayan
# Processing Record 26 of Set 13 | coos bay
# Processing Record 27 of Set 13 | duz
# City not found. Skipping...
# Processing Record 28 of Set 13 | honiara
# Processing Record 29 of Set 13 | walvis bay
# Processing Record 30 of Set 13 | mayo
# Processing Record 31 of Set 13 | huancabamba
# Processing Record 32 of Set 13 | zemio
# Processing Record 33 of Set 13 | san pedro de macoris
# Processing Record 34 of Set 13 | novo aripuana
# Processing Record 35 of Set 13 | woodward
# Processing Record 36 of Set 13 | tommot
# Processing Record 37 of Set 13 | inuvik
# Processing Record 38 of Set 13 | kosh-agach
# Processing Record 39 of Set 13 | gagesti
# Processing Record 40 of Set 13 | goodyear
# Processing Record 41 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 42 of Set 13 | ust-kut
# Processing Record 43 of Set 13 | hearst
# Processing Record 44 of Set 13 | rosetta
# Processing Record 45 of Set 13 | anjozorobe
# Processing Record 46 of Set 13 | watsa
# Processing Record 47 of Set 13 | kot putli
# City not found. Skipping...
# Processing Record 48 of Set 13 | broome
# Processing Record 49 of Set 13 | sirjan
# Processing Record 50 of Set 13 | abucayan
# Processing Record 1 of Set 14 | aiken
# Processing Record 2 of Set 14 | deder
# Processing Record 3 of Set 14 | praya
# Processing Record 4 of Set 14 | manica
# Processing Record 5 of Set 14 | duzce
# Processing Record 6 of Set 14 | polunochnoye
# Processing Record 7 of Set 14 | pingyin
# Processing Record 8 of Set 14 | lakes entrance
# Processing Record 9 of Set 14 | yantai
# Processing Record 10 of Set 14 | cocentaina
# Processing Record 11 of Set 14 | matay
# Processing Record 12 of Set 14 | myanaung
# Processing Record 13 of Set 14 | mkushi
# Processing Record 14 of Set 14 | brownwood
# Processing Record 15 of Set 14 | ronne
# Processing Record 16 of Set 14 | beausejour
# Processing Record 17 of Set 14 | azul
# Processing Record 18 of Set 14 | mareeba
# Processing Record 19 of Set 14 | borlange
# City not found. Skipping...
# Processing Record 20 of Set 14 | brandon
# Processing Record 21 of Set 14 | gilleleje
# Processing Record 22 of Set 14 | pirovskoye
# Processing Record 23 of Set 14 | dinajpur
# Processing Record 24 of Set 14 | kovrov
# Processing Record 25 of Set 14 | yar
# Processing Record 26 of Set 14 | kabare
# Processing Record 27 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 28 of Set 14 | faya
# Processing Record 29 of Set 14 | ayr
# Processing Record 30 of Set 14 | svetlyy
# Processing Record 31 of Set 14 | melbu
# Processing Record 32 of Set 14 | harper
# Processing Record 33 of Set 14 | dwarka
# Processing Record 34 of Set 14 | saint anthony
# Processing Record 35 of Set 14 | amarillo
# Processing Record 36 of Set 14 | chiang rai
# Processing Record 37 of Set 14 | bourail
# Processing Record 38 of Set 14 | kudahuvadhoo
# Processing Record 39 of Set 14 | jacareacanga
# Processing Record 40 of Set 14 | yar-sale
# Processing Record 41 of Set 14 | brokopondo
# Processing Record 42 of Set 14 | uvalde
# Processing Record 43 of Set 14 | samarai
# Processing Record 44 of Set 14 | qixingtai
# Processing Record 45 of Set 14 | zhicheng
# Processing Record 46 of Set 14 | derzhavinsk
# Processing Record 47 of Set 14 | lodwar
# Processing Record 48 of Set 14 | chebarkul
# Processing Record 49 of Set 14 | beltangadi
# Processing Record 50 of Set 14 | homer
# Processing Record 1 of Set 15 | quatre cocos
# Processing Record 2 of Set 15 | wattegama
# Processing Record 3 of Set 15 | qui nhon
# Processing Record 4 of Set 15 | mount isa
# Processing Record 5 of Set 15 | ayacucho
# Processing Record 6 of Set 15 | moose factory
# Processing Record 7 of Set 15 | manzhouli
# Processing Record 8 of Set 15 | dimapur
# Processing Record 9 of Set 15 | banjar
# Processing Record 10 of Set 15 | riyadh
# Processing Record 11 of Set 15 | sile
# Processing Record 12 of Set 15 | qaqortoq
# Processing Record 13 of Set 15 | qeshm
# Processing Record 14 of Set 15 | dullewala
# Processing Record 15 of Set 15 | sun city west
# Processing Record 16 of Set 15 | lydenburg
# Processing Record 17 of Set 15 | natal
# Processing Record 18 of Set 15 | tawang
# Processing Record 19 of Set 15 | siquijor
# Processing Record 20 of Set 15 | borogontsy
# Processing Record 21 of Set 15 | invermere
# Processing Record 22 of Set 15 | abnub
# Processing Record 23 of Set 15 | orlik
# Processing Record 24 of Set 15 | saurimo
# Processing Record 25 of Set 15 | casablanca
# Processing Record 26 of Set 15 | iracoubo
# Processing Record 27 of Set 15 | laguna
# Processing Record 28 of Set 15 | miracema do tocantins
# Processing Record 29 of Set 15 | ukiah
# Processing Record 30 of Set 15 | salinopolis
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather
# Out:
# {'coord': {'lon': -47.3561, 'lat': -0.6136},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 77.49,
#   'feels_like': 78.69,
#   'temp_min': 77.49,
#   'temp_max': 77.49,
#   'pressure': 1009,
#   'humidity': 80,
#   'sea_level': 1009,
#   'grnd_level': 1009},
#  'visibility': 10000,
#  'wind': {'speed': 7.07, 'deg': 69, 'gust': 7.61},
#  'clouds': {'all': 16},
#  'dt': 1664944722,
#  'sys': {'country': 'BR', 'sunrise': 1664960052, 'sunset': 1665003676},
#  'timezone': -10800,
#  'id': 3389822,
#  'name': 'Salinópolis',
#  'cod': 200}

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 673

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#    latitud  longitude  temperature  humidity  cloudiness  wind_speed country  \
# 0 -34.5322    20.0403        50.61        89           0        6.69      ZA
# 1  20.8947  -156.4700        82.42        81          75       17.27      US
# 2  60.9500    25.9333        41.85        69         100       12.64      FI
# 3  18.0858   -15.9785        82.33        59          38        7.52      MR
# 4  22.9333    57.5333        75.92        66          23        2.35      OM
# 5  41.3712   -73.4140        50.65        84         100        6.91      US
# 6  50.6789   156.1250        52.66        77          97       12.08      RU
# 7  -8.9266   125.4092        68.23        77          99        1.48      TL
# 8  59.7035    30.7861        48.09        94         100        8.14      RU
# 9  53.9202   102.0442        29.16        93         100        2.91      RU
#
#        description             city
# 0        clear sky       Bredasdorp
# 1       light rain          Kahului
# 2  overcast clouds          Nastola
# 3       light rain       Nouakchott
# 4       few clouds            Nizwá
# 5       light rain           Bethel
# 6  overcast clouds  Severo-Kuril'sk
# 7  overcast clouds            Airai
# 8  overcast clouds       Nikolskoye
# 9       light snow             Zima

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['latitud', 'longitude', 'temperature', 'humidity', 'cloudiness',
#        'wind_speed', 'country', 'description', 'city'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE
new_column_order =['city','country','latitud','longitude','temperature','humidity','cloudiness','wind_speed', 'description']

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE
df = city_data_df[new_column_order]
# Display sample data
# YOUR CODE HERE
df.head(10)
# Out:
#           city country  latitud  longitude  temperature  humidity  cloudiness  \
# 0      Peniche      PT  39.3558    -9.3811        59.11        94           0
# 1   Rio Grande      BR -32.0350   -52.0986        58.01        91           0
# 2       Albany      US  42.6001   -73.9662        52.39        82         100
# 3      Rikitea      PF -23.1203  -134.9692        70.29        62          89
# 4    Pouembout      NC -21.1333   164.9000        78.06        50           3
# 5    Jamestown      US  42.0970   -79.2353        49.64        70           0
# 6  Port Alfred      ZA -33.5906    26.8910        60.53        85           0
# 7    Mahébourg      MU -20.4081    57.7000        75.25        68          40
# 8    Zacatepec      MX  18.6500   -99.2000        77.43        80          12
# 9     Paracatu      BR -17.2222   -46.8747        67.05        90          99
#
#    wind_speed       description
# 0        8.90         clear sky
# 1        8.52         clear sky
# 2        4.34   overcast clouds
# 3       23.69   overcast clouds
# 4       10.56         clear sky
# 5       10.36         clear sky
# 6        8.70         clear sky
# 7       11.50  scattered clouds
# 8        1.32        few clouds
# 9        2.86   overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
df.dtypes
# Out:
# city            object
# country         object
# latitud        float64
# longitude      float64
# temperature    float64
# humidity         int64
# cloudiness       int64
# wind_speed     float64
# description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE
output_data_file = "../weather_data/cities2.csv"
# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
city_data_df.to_csv(output_data_file, index_label="City_ID")
